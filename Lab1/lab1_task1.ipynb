# %% [markdown]
# <a href="https://colab.research.google.com/github/it22188236/DL-Labs/blob/main/Lab1/lab1_task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Task 1
# Out:
# (2, 3, 4)
# 3
# 24
# numpy.ndarray

# %%
import numpy as np
np.random.exponential(4,4)
# Out:
# array([2.5147479 , 4.56770826, 1.10336993, 0.67787499])

# %%
scale = 1.0
np.random.exponential(scale=scale,size=(4,4))
# Out:
# array([[0.22330064, 1.67281344, 0.47104614, 3.3787357 ],
#        [0.34208703, 0.84976244, 0.95562823, 0.24786205],
#        [0.83464379, 0.95715023, 0.36805313, 0.61470931],
#        [0.50513122, 0.37059335, 0.23274121, 0.51825532]])

# %%
np.random.exponential(scale=scale,size=(100000,1))
# Out:
# array([[1.0164987 ],
#        [1.40654032],
#        [0.2813305 ],
#        ...,
#        [0.88327204],
#        [1.53602269],
#        [6.97015504]])

# %%
#2
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

plt.hist(np.random.rand(100000), density=True, bins=100, histtype="step", color="blue",
label="rand")
plt.axis([-2.5, 2.5, 0, 1.1])
plt.legend(loc = "upper left")
plt.title("Random distributions")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

# %%
#3
x = np.linspace(-5,5);
y = np.linspace(-5,5);

X,Y = np.meshgrid(x,y)
Z = X**2 + Y**2
fig = plt.figure();
ax = fig.add_subplot(111,projection="3d")
ax.plot_surface(X, Y, Z)
plt.show()

# %%
# #4
# import pandas as pd
# from matplotlib import pyplot as plt
# %matplotlib inline
# import seaborn as sns

# !wget -q https://elitedatascience.com/wp-content/uploads/2022/07/Pokemon.csv
# # Read dataset
# df = pd.read_csv('Pokemon.csv', index_col=0, encoding='latin')
# # df.head()
# stats_df = df.drop(['Total', 'Stage', 'Legendary'], axis=1)
# corr = stats_df.corr()
# plt.figure(figsize=(9,8))
# sns.heatmap(corr)

import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# Download and read dataset
# !wget -q https://elitedatascience.com/wp-content/uploads/2022/07/Pokemon.csv
df = pd.read_csv('Pokemon.csv', index_col=0, encoding='latin')

# Drop non-numerical columns and specified columns
stats_df = df.drop(['Name', 'Type 1', 'Type 2', 'Total', 'Stage', 'Legendary'], axis=1, errors='ignore')

# Check column types to confirm they are numerical
print(stats_df.dtypes)

# Compute correlation matrix
corr = stats_df.corr()

# Create heatmap
plt.figure(figsize=(9,8))
sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.show()
# Out:
# HP         int64
# Attack     int64
# Defense    int64
# Sp. Atk    int64
# Sp. Def    int64
# Speed      int64
# dtype: object
